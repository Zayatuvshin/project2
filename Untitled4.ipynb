# %%
import pandas as pd

# %%
df = pd.read_csv("export1.csv")

# %%
df
# Out:
#                                         барааны бүлэг        1995        1996  \
# 0       Мал, амьтан, тэдгээрийн гаралтай бүтээгдэхүүн   10,414.30   14,136.80
# 1                      Ургамлын гаралтай бүтээгдэхүүн    4,939.30    1,882.00
# 2              Мал, амьтан, ургамлын гаралтай өөх тос       36.00      219.20
# 3                          Хүнсний бэлэн бүтээгдэхүүн    2,541.50    1,746.00
# 4                                  Эрдэс бүтээгдэхүүн  309,976.40  242,778.30
# 5         Химийн болон химийн үйлдвэрийн бүтээгдэхүүн    1,538.70    2,148.60
# 6              Хуванцар, каучук, түүгээр хийсэн эдлэл       98.60      850.90
# 7   Түүхий болон боловсруулсан арьс, шир, ангийн ү...   23,733.40   23,032.70
# 8                                    Мод, модон эдлэл    4,864.80   10,193.70
# 9       Целлюлоз, цаас, картон,тэдгээрээр хийсэн зүйл      187.60      126.20
# 10                   Нэхмэл болон нэхмэл бүтээгдэхүүн   80,730.60  103,496.50
# ...

# %%
df = df.drop(index=[2, 3, 6, 9, 11, 12, 15, 16, 17, 18, 19])
df = df.reset_index(drop=True)

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].replace(",", "", regex=True).astype(float)

print(df.isnull().sum())
# Out:
# барааны бүлэг    0
# 1995             0
# 1996             0
# 1997             0
# 1998             0
# 1999             0
# 2000             0
# 2001             0
# 2002             0
# 2003             0
# 2004             0
# 2005             0
# 2006             0
# 2007             0
# 2008             0
# 2009             0
# 2010             0
# 2011             0
# 2012             0
# 2013             0
# 2014             0
# 2015             0
# 2016             0
# 2017             0
# 2018             0
# 2019             0
# 2020             0
# 2021             0
# 2022             0
# 2023             0
# dtype: int64

# %%
df
# Out:
#                                        барааны бүлэг      1995      1996  \
# 0      Мал, амьтан, тэдгээрийн гаралтай бүтээгдэхүүн   10414.3   14136.8
# 1                     Ургамлын гаралтай бүтээгдэхүүн    4939.3    1882.0
# 2                                 Эрдэс бүтээгдэхүүн  309976.4  242778.3
# 3        Химийн болон химийн үйлдвэрийн бүтээгдэхүүн    1538.7    2148.6
# 4  Түүхий болон боловсруулсан арьс, шир, ангийн ү...   23733.4   23032.7
# 5                                   Мод, модон эдлэл    4864.8   10193.7
# 6                   Нэхмэл болон нэхмэл бүтээгдэхүүн   80730.6  103496.5
# 7         Үнэт, хагас үнэт чулуу, метал гоёлын зүйлс       4.4       0.5
# 8   Үндсэн төмөрлөг болонтүүгээр хийсэн бүтээгдэхүүн   17070.3   15969.2
#
#        1997      1998      1999      2000      2001      2002      2003  ...  \
# 0   18664.2   18793.2   21864.5   23102.5   26369.2   28864.2   22505.4  ...
# 1     359.8     370.8      68.0     230.4    1090.4    2747.2    1144.4  ...
# ...

# %%
translation_dict = {
    "Мал, амьтан, тэдгээрийн гаралтай бүтээгдэхүүн": "Animals and Animal Products",
    "Ургамлын гаралтай бүтээгдэхүүн": "Plant Products",
    "Эрдэс бүтээгдэхүүн": "Mineral products",
    "Химийн болон химийн үйлдвэрийн бүтээгдэхүүн": "Chemical products",
    "Түүхий болон боловсруулсан арьс, шир, ангийн үс,эдгээрээр хийсэн эдлэл": "Raw hides skin and fur products",
    "Мод, модон эдлэл": "Wooden products",
    "Нэхмэл болон нэхмэл бүтээгдэхүүн": "Crocheted products",
    "Үнэт, хагас үнэт чулуу, метал гоёлын зүйлс": "Precious stones and metal products",
    "Үндсэн төмөрлөг болонтүүгээр хийсэн бүтээгдэхүүн": "Basic Ferrous Metal Products"
}

df["барааны бүлэг"] = df["барааны бүлэг"].replace(translation_dict)

# %%
df = df.rename(columns={"барааны бүлэг": "Goods Category"})

# %%
df = df.melt(id_vars=["Goods Category"], 
                  var_name="Year", 
                  value_name="Export Value")


print(df.head())
# Out:
#                     Goods Category  Year Export Value
# 0      Animals and Animal Products  1995      10414.3
# 1                   Plant Products  1995       4939.3
# 2                 Mineral products  1995     309976.4
# 3                Chemical products  1995       1538.7
# 4  Raw hides skin and fur products  1995      23733.4

# %%
df = df.rename(columns = {"Export Value": "Value(USD)"})

# %%
df_c['Year'] = pd.to_datetime(df_c['Year'], format='%Y')

# %%
df_c['Year'] = df_c['Year'].dt.year

# %%
df.to_csv("Export2.csv", index=False)

# %%
pd.read_csv("Export2.csv")
# Out:
#                          Goods Category  Year  Value(USD)
# 0           Animals and Animal Products  1995     10414.3
# 1                        Plant Products  1995      4939.3
# 2                      Mineral products  1995    309976.4
# 3                     Chemical products  1995      1538.7
# 4       Raw hides skin and fur products  1995     23733.4
# ..                                  ...   ...         ...
# 256     Raw hides skin and fur products  2023      4758.5
# 257                     Wooden products  2023       365.6
# 258                  Crocheted products  2023    451152.6
# 259  Precious stones and metal products  2023    762000.6
# 260        Basic Ferrous Metal Products  2023    123035.2
#
# [261 rows x 3 columns]

# %%
df_c = pd.read_csv("export_countries.csv")

# %%
df_c = df_c.rename(columns = {"Улс орон": "Continent"})

# %%
translation_dict = {
    "Европ": "Europe",
    "Ази": "Asia",
    "Африк": "Africa",
    "Америк": "America",
    "Австрали": "Australia"
}

df_c["Continent"] = df_c["Continent"].replace(translation_dict)

# %%
df_c = df_c.melt(id_vars=["Continent"], 
                  var_name="Year", 
                  value_name="Export Value")


print(df_c.head())
# Out:
#    Continent  Year Export Value
# 0     Europe  2005    171,066.7
# 1       Asia  2005    602,922.2
# 2     Africa  2005        143.9
# 3    America  2005    275,469.6
# 4  Australia  2005     14,280.8

# %%
df_c.iloc[:, 1:] = df_c.iloc[:, 1:].replace(",", "", regex=True).astype(float)

print(df_c.isnull().sum())
# Out:
# Continent       0
# Year            0
# Export Value    0
# dtype: int64

# %%
df_c.to_csv("export_countries.csv", index=False)

# %%
# !pip install statsmodels.tsa.arima.model
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodels.tsa.arima.model (from versions: none)
# ERROR: No matching distribution found for statsmodels.tsa.arima.model

# %%
pip install --upgrade statsmodels
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The system cannot find the path specified.

# %%
# !pip install prophet
# Out:
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB 330.3 kB/s eta 0:00:41
#    ---------------------------------------- 0.1/13.3 MB 563.7 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/13.3 MB 525.1 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/13.3 MB 711.9 kB/s eta 0:00:19
#     --------------------------------------- 0.2/13.3 MB 787.7 kB/s eta 0:00:17
#     --------------------------------------- 0.2/13.3 MB 801.7 kB/s eta 0:00:17
#     --------------------------------------- 0.3/13.3 MB 905.4 kB/s eta 0:00:15
#    - -------------------------------------- 0.4/13.3 MB 998.3 kB/s eta 0:00:13
#    - -------------------------------------- 0.4/13.3 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/13.3 MB 1.1 MB/s eta 0:00:13
# ...
